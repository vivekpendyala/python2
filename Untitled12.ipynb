# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:/Users/VIVEK/OneDrive/Desktop/AI-ML/haberman.csv.')

# %%
df.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
df.describe()
# Out:
#                30          64           1         1.1
# count  305.000000  305.000000  305.000000  305.000000
# mean    52.531148   62.849180    4.036066    1.265574
# std     10.744024    3.254078    7.199370    0.442364
# min     30.000000   58.000000    0.000000    1.000000
# 25%     44.000000   60.000000    0.000000    1.000000
# 50%     52.000000   63.000000    1.000000    1.000000
# 75%     61.000000   66.000000    4.000000    2.000000
# max     83.000000   69.000000   52.000000    2.000000

# %% [markdown]
# -- The above method will provide the mean , standad deviation values in the datafram

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(df.corr())

# %%
sns.pairplot(df)

# %%
plt.plot(df)

# %%
sns.scatterplot(df['30'],df['1.1'])

# %%
plt.boxplot(df['30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14736358>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x147367c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1475ceb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14736b20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14736ca0>],
#  'means': []}

# %%
plt.boxplot(df['64'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1479c8c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1479cc28>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1479c718>],
#  'medians': [<matplotlib.lines.Line2D at 0x1479cf88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14749118>],
#  'means': []}

# %%
plt.boxplot(df['1'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14767d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x147760b8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14767b68>],
#  'medians': [<matplotlib.lines.Line2D at 0x14776418>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14776580>],
#  'means': []}

# %%
plt.boxplot(df['1.1'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x147e61a8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x147e6508>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x147dbfd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x147e6838>],
#  'fliers': [<matplotlib.lines.Line2D at 0x147e69b8>],
#  'means': []}

# %% [markdown]
# From the above plot's i can only assume that there is no correlation with each other
